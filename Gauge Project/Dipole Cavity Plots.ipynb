# %%
#Import the Dipole Cavity System Class
from Dipole_Cavity_Class import Dipole_Cavity_System

# %%
#Define the system parameters
w = 2.47*0.658*(10**-3) 
Ed = 38.77419*w
beta = 3.581291
detuning = 1 #detuning between cavity and dipole

#Create an instance of the Dipole Cavity System
mmult = 15
nmult = 20
Dip = Dipole_Cavity_System(mmult, nmult, Ed, beta, detuning, True)

# %%
#Plot the Energy Levels
Dip.Paper_Plot_Energy_Levels(6, 50, 6, 4)

#Plot Energy Transitions
Dip.Paper_Plot_Energy_Transition(6, 50, 6, 4)

# %%
#Plot Coulomb Gauge Photon Number
Dip.Plot_Operator_Expectation(4, Dip.CG_Photon_Number, 50, "$\langle n_{E_T} \\rangle$", 6, 4)
# Out:
# /Users/daneyles/Desktop/Github_Repos/PhD Projects/.venv_PhD/lib/python3.11/site-packages/matplotlib/cbook.py:1719: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Users/daneyles/Desktop/Github_Repos/PhD Projects/.venv_PhD/lib/python3.11/site-packages/matplotlib/cbook.py:1355: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
#Plot CG Matter Excitations
ylabel = "$\langle \Gamma \\rangle$"
Op = Dip.CG_Matter_Exciations
Dip.Plot_Operator_Expectation(4, Op, 50, ylabel)

# %%
#Plot Fidelity with exact state
Dip.Paper_Plot_Multipolar_Fidelity(50)
