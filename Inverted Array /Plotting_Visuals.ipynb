# %%
import sys
from pathlib import Path

from Data_Generation_Functions import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       1 import sys
#       2 from pathlib import Path
# ----> 4 from Data_Generation_Functions import *
#
# File ~/Desktop/Github_Repos/PhD Projects/Inverted Array /Data_Generation_Functions.py:6
#       3 sys.path.append(str(Path(__file__).resolve().parents[1]))
#       5 from Classes.File_Management_Classes import Read_Write_Class
# ----> 6 from Classes.G2_Classes import *
#       7 from Classes.Qutip_Class import *
#       8 from Classes.SMUTHI_Environment_Class import *
#
# File ~/Desktop/Github_Repos/PhD Projects/Classes/G2_Classes.py:4
#       1 from enum import Enum
#       2 import sys
# ----> 4 from Unit_Converter_Classes import *
#       5 from SMUTHI_Environment_Class import *
#       6 from Qutip_Class import *
#
# ModuleNotFoundError: No module named 'Unit_Converter_Classes'
